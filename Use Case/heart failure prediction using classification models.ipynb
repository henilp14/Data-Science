# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("C:\\Users\\al6436\\Desktop\\Use Case\\heart_failure_prediction.csv")
df.head()
# Out:
#    Age  Gender Chest_Pain_Type  Resting_BP  Cholesterol  Fasting_Blood_Sugar  \
# 0   69    Male        Atypical         106          250                    1
# 1   32    Male     Non-anginal         124          396                    1
# 2   89  Female     Non-anginal         164          256                    1
# 3   78  Female         Typical         116          297                    1
# 4   38    Male     Non-anginal          88          386                    1
#
#                     Resting_ECG  Max_Heart_Rate  Exercise_Induced_Angina  \
# 0         ST-T Wave Abnormality             171                        0
# 1  Left Ventricular Hypertrophy              73                        0
# 2  Left Ventricular Hypertrophy             157                        0
# 3                        Normal             163                        1
# 4         ST-T Wave Abnormality             123                        1
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 20 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Age                      10000 non-null  int64
#  1   Gender                   10000 non-null  object
#  2   Chest_Pain_Type          10000 non-null  object
#  3   Resting_BP               10000 non-null  int64
#  4   Cholesterol              10000 non-null  int64
#  5   Fasting_Blood_Sugar      10000 non-null  int64
#  6   Resting_ECG              10000 non-null  object
#  7   Max_Heart_Rate           10000 non-null  int64
#  8   Exercise_Induced_Angina  10000 non-null  int64
#  9   Oldpeak                  10000 non-null  float64
#  10  Slope                    10000 non-null  object
#  11  Num_Major_Vessels        10000 non-null  int64
#  12  Thalassemia              10000 non-null  object
#  13  Diabetes                 10000 non-null  int64
# ...

# %%
df.shape
# Out:
# (10000, 20)

# %%
df.describe()
# Out:
#                 Age   Resting_BP   Cholesterol  Fasting_Blood_Sugar  \
# count  10000.000000  10000.00000  10000.000000         10000.000000
# mean      58.584900    139.56920    247.206200             0.505400
# std       23.645835     34.86205     86.862739             0.499996
# min       18.000000     80.00000    100.000000             0.000000
# 25%       38.000000    109.00000    171.000000             0.000000
# 50%       59.000000    140.00000    247.000000             1.000000
# 75%       79.000000    170.00000    322.000000             1.000000
# max       99.000000    199.00000    399.000000             1.000000
#
#        Max_Heart_Rate  Exercise_Induced_Angina       Oldpeak  \
# count    10000.000000             10000.000000  1.000000e+04
# mean       129.346600                 0.507200  9.200000e-01
# std         40.316689                 0.499973  6.250868e-14
# min         60.000000                 0.000000  9.200000e-01
# ...

# %%
df.isnull().sum()
# Out:
# Age                           0
# Gender                        0
# Chest_Pain_Type               0
# Resting_BP                    0
# Cholesterol                   0
# Fasting_Blood_Sugar           0
# Resting_ECG                   0
# Max_Heart_Rate                0
# Exercise_Induced_Angina       0
# Oldpeak                       0
# Slope                         0
# Num_Major_Vessels             0
# Thalassemia                   0
# Diabetes                      0
# Smoking_History               0
# Alcohol_Consumption        3350
# Physical_Activity_Level       0
# Family_History                0
# BMI                           0
# Heart_Failure                 0
# dtype: int64

# %%
df_1 = df.dropna()
df_1.isnull().sum()
# Out:
# Age                        0
# Gender                     0
# Chest_Pain_Type            0
# Resting_BP                 0
# Cholesterol                0
# Fasting_Blood_Sugar        0
# Resting_ECG                0
# Max_Heart_Rate             0
# Exercise_Induced_Angina    0
# Oldpeak                    0
# Slope                      0
# Num_Major_Vessels          0
# Thalassemia                0
# Diabetes                   0
# Smoking_History            0
# Alcohol_Consumption        0
# Physical_Activity_Level    0
# Family_History             0
# BMI                        0
# Heart_Failure              0
# dtype: int64

# %%
df_1.describe()
# Out:
#                Age   Resting_BP  Cholesterol  Fasting_Blood_Sugar  \
# count  6650.000000  6650.000000  6650.000000          6650.000000
# mean     58.489624   139.341504   247.224812             0.505865
# std      23.585532    34.650192    87.183026             0.500003
# min      18.000000    80.000000   100.000000             0.000000
# 25%      38.000000   109.000000   171.000000             0.000000
# 50%      59.000000   139.500000   246.000000             1.000000
# 75%      79.000000   169.000000   323.000000             1.000000
# max      99.000000   199.000000   399.000000             1.000000
#
#        Max_Heart_Rate  Exercise_Induced_Angina       Oldpeak  \
# count     6650.000000              6650.000000  6.650000e+03
# mean       129.669925                 0.507368  9.200000e-01
# std         40.274749                 0.499983  5.751388e-14
# min         60.000000                 0.000000  9.200000e-01
# 25%         95.000000                 0.000000  9.200000e-01
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

df_selected = df[["Age", "Resting_BP", "Cholesterol", "Max_Heart_Rate", "Num_Major_Vessels", "Heart_Failure"]].copy()

df_selected["Heart_Failure"] = df_selected["Heart_Failure"].astype("category")

sns.pairplot(df_selected, hue="Heart_Failure", diag_kind="kde")
plt.show()

# %%
numeric_df = df.select_dtypes(include=[np.number])

# Correlation heatmap
plt.figure(figsize=(12, 8))
sns.heatmap(numeric_df.corr(), annot=True, cmap="coolwarm", fmt=".2f", linewidths=0.5)
plt.title("Correlation Matrix of Numerical Features")
plt.show()

# %%
from scipy.stats import chi2_contingency

categorical_features = ["Gender", "Chest_Pain_Type", "Resting_ECG", "Slope", "Thalassemia", 
                        "Smoking_History", "Alcohol_Consumption", "Physical_Activity_Level"]

chi2_results = {}
for feature in categorical_features:
    contingency_table = pd.crosstab(df[feature], df["Heart_Failure"])
    chi2, p, _, _ = chi2_contingency(contingency_table)
    chi2_results[feature] = p

chi2_df = pd.DataFrame(chi2_results.items(), columns=["Feature", "P-Value"]).sort_values(by="P-Value")
chi2_df
# Out:
#                    Feature   P-Value
# 7  Physical_Activity_Level  0.066043
# 0                   Gender  0.192402
# 4              Thalassemia  0.365594
# 2              Resting_ECG  0.514035
# 6      Alcohol_Consumption  0.539153
# 5          Smoking_History  0.902506
# 1          Chest_Pain_Type  0.954140
# 3                    Slope  0.971742

# %%
plt.figure(figsize=(8, 6))
sns.barplot(data=df, x="Chest_Pain_Type", y="Cholesterol", hue="Heart_Failure", palette="magma")
plt.title("Average Cholesterol Levels by Chest Pain Type and Heart Failure")
plt.xlabel("Chest Pain Type")
plt.ylabel("Average Cholesterol")
plt.legend(title="Heart Failure")
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.boxplot(data=df, x="Heart_Failure", y="Resting_BP", palette="coolwarm")
plt.title("Boxen Plot of Resting BP by Heart Failure")
plt.xlabel("Heart Failure")
plt.ylabel("Resting BP")
plt.show()
# Out:
# C:\Users\al6436\AppData\Local\Temp\ipykernel_8372\1891831605.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=df, x="Heart_Failure", y="Resting_BP", palette="coolwarm")

# %%
plt.figure(figsize=(8, 6))
sns.kdeplot(data=df, x="Max_Heart_Rate", hue="Chest_Pain_Type", fill=True, palette="coolwarm", alpha=0.5)
plt.title("Age Distribution by Max Heart Rate Status")
plt.xlabel("Age")
plt.ylabel("Density")
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.kdeplot(data=df, x="Age", hue="Heart_Failure", fill=True, palette="coolwarm", alpha=0.5)
plt.title("Age Distribution by Heart Failure Status")
plt.xlabel("Age")
plt.ylabel("Density")
plt.show()

# %%
plt.figure(figsize=(6, 4))
sns.countplot(x=df["Heart_Failure"], palette="Set2")
plt.title("Count of Heart Failure Cases")
plt.xlabel("Heart Failure (0 = No, 1 = Yes)")
plt.ylabel("Count")
plt.show()
# Out:
# C:\Users\al6436\AppData\Local\Temp\ipykernel_8372\2744441534.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=df["Heart_Failure"], palette="Set2")

# %%
# Re-import necessary libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import accuracy_score, classification_report

# Encode categorical features
label_encoders = {}
categorical_features = ["Gender", "Chest_Pain_Type", "Resting_ECG", "Slope", "Thalassemia", 
                        "Smoking_History", "Alcohol_Consumption", "Physical_Activity_Level"]
df_encoded = df.copy()

for col in categorical_features:
    le = LabelEncoder()
    df_encoded[col] = le.fit_transform(df_encoded[col])
    label_encoders[col] = le

# Define target variable
y = df_encoded["Heart_Failure"]

# Use all features for training
all_features = df_encoded.columns.drop("Heart_Failure")
X_all = df_encoded[all_features]

# Split data into training and testing sets
X_train_all, X_test_all, y_train, y_test = train_test_split(X_all, y, test_size=0.2, random_state=42)

# Train Random Forest model with all features
rf_all = RandomForestClassifier(n_estimators=100, random_state=42)
rf_all.fit(X_train_all, y_train)

# Make predictions
y_pred_all = rf_all.predict(X_test_all)

# Evaluate performance
accuracy_all = accuracy_score(y_test, y_pred_all)
report_all = classification_report(y_test, y_pred_all)

# Get feature importances
feature_importances = rf_all.feature_importances_

# Create a DataFrame for visualization
importance_df = pd.DataFrame({"Feature": all_features, "Importance": feature_importances})
importance_df = importance_df.sort_values(by="Importance", ascending=False)

# Plot feature importance
plt.figure(figsize=(10, 5))
sns.barplot(x="Importance", y="Feature", data=importance_df, palette="viridis")
plt.title("Feature Importance in Random Forest Model")
plt.xlabel("Importance Score")
plt.ylabel("Feature")
plt.show()

# Display accuracy and classification report
accuracy_all, report_all
# Out:
# C:\Users\al6436\AppData\Local\Temp\ipykernel_8372\17034355.py:53: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x="Importance", y="Feature", data=importance_df, palette="viridis")
# (0.5165,
#  '              precision    recall  f1-score   support\n\n           0       0.51      0.53      0.52       985\n           1       0.52      0.50      0.51      1015\n\n    accuracy                           0.52      2000\n   macro avg       0.52      0.52      0.52      2000\nweighted avg       0.52      0.52      0.52      2000\n')

# %%
# Import necessary libraries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

# Load dataset
file_path = "heart_failure_prediction.csv"  # Change this to your actual file path
df = pd.read_csv(file_path)

# 🔹 Handle categorical variables using Label Encoding
categorical_features = ["Gender", "Chest_Pain_Type", "Resting_ECG", "Slope", "Thalassemia", 
                        "Smoking_History", "Alcohol_Consumption", "Physical_Activity_Level"]

label_encoders = {}
for col in categorical_features:
    le = LabelEncoder()
    df[col] = le.fit_transform(df[col])
    label_encoders[col] = le  # Store encoder for future use

# 🔹 Define Features (X) and Target (y)
X = df.drop(columns=["Heart_Failure"])  # Independent Variables
y = df["Heart_Failure"]  # Target Variable

# 🔹 Scale Numerical Features
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# 🔹 Split into Training and Testing Sets (80-20 Split)
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=42)

# 🔹 Train a Random Forest Model
model = RandomForestClassifier(n_estimators=100, random_state=42)
model.fit(X_train, y_train)

# 🔹 Make Predictions
y_pred = model.predict(X_test)

# 🔹 Evaluate the Model
print("🔹 Model Accuracy:", accuracy_score(y_test, y_pred))
print("🔹 Classification Report:\n", classification_report(y_test, y_pred))

# 🔹 Confusion Matrix Visualization
plt.figure(figsize=(5, 4))
sns.heatmap(confusion_matrix(y_test, y_pred), annot=True, fmt='d', cmap="coolwarm")
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.title("Confusion Matrix")
plt.show()
# Out:
# 🔹 Model Accuracy: 0.5175
# 🔹 Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.51      0.53      0.52       985
#            1       0.53      0.50      0.51      1015
#
#     accuracy                           0.52      2000
#    macro avg       0.52      0.52      0.52      2000
# weighted avg       0.52      0.52      0.52      2000

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

# Initialize Logistic Regression model
log_model = LogisticRegression(max_iter=500, random_state=42)

# Train the model
log_model.fit(X_train, y_train)

# Make predictions
y_pred_log = log_model.predict(X_test)

# Evaluate the Model
print("🔹 Logistic Regression Accuracy:", accuracy_score(y_test, y_pred_log))
print("🔹 Classification Report:\n", classification_report(y_test, y_pred_log))

# Confusion Matrix
plt.figure(figsize=(5, 4))
sns.heatmap(confusion_matrix(y_test, y_pred_log), annot=True, fmt='d', cmap="coolwarm")
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.title("Confusion Matrix - Logistic Regression")
plt.show()
# Out:
# 🔹 Logistic Regression Accuracy: 0.4995
# 🔹 Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.49      0.44      0.47       985
#            1       0.51      0.55      0.53      1015
#
#     accuracy                           0.50      2000
#    macro avg       0.50      0.50      0.50      2000
# weighted avg       0.50      0.50      0.50      2000

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score, classification_report
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)
knn_model = KNeighborsClassifier(n_neighbors=15)  # You can tune "n_neighbors"
knn_model.fit(X_train_scaled, y_train)
y_pred = knn_model.predict(X_test_scaled)
accuracy = accuracy_score(y_test, y_pred)
print(f"Model Accuracy: {accuracy:.4f}")  

print("🔹 Classification Report:")
print(classification_report(y_test, y_pred))
# Out:
# Model Accuracy: 0.5150
# 🔹 Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.51      0.48      0.49       985
#            1       0.52      0.55      0.53      1015
#
#     accuracy                           0.52      2000
#    macro avg       0.51      0.51      0.51      2000
# weighted avg       0.51      0.52      0.51      2000
# C:\Users\al6436\AppData\Local\anaconda3\Lib\site-packages\joblib\externals\loky\backend\context.py:136: UserWarning: Could not find the number of physical cores for the following reason:
# [WinError 2] The system cannot find the file specified
# Returning the number of logical cores instead. You can silence this warning by setting LOKY_MAX_CPU_COUNT to the number of cores you want to use.
#   warnings.warn(
#   File "C:\Users\al6436\AppData\Local\anaconda3\Lib\site-packages\joblib\externals\loky\backend\context.py", line 257, in _count_physical_cores
#     cpu_info = subprocess.run(
# ...

# %%
import matplotlib.pyplot as plt

errors = []
for k in range(1, 21):
    knn = KNeighborsClassifier(n_neighbors=k)
    knn.fit(X_train_scaled, y_train)
    y_pred_k = knn.predict(X_test_scaled)
    errors.append(1 - accuracy_score(y_test, y_pred_k))

# Plot Error Rate vs. k
plt.figure(figsize=(8, 5))
plt.plot(range(1, 21), errors, marker='o', linestyle='dashed', color='red')
plt.xlabel("Number of Neighbors (k)")
plt.ylabel("Error Rate")
plt.title("Choosing the Best k for KNN")
plt.show()

# %%
# Re-import necessary libraries since execution state was reset
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score


# Selecting relevant numerical features for KNN
features = ["Age", "Resting_BP", "Cholesterol", "Max_Heart_Rate", "Oldpeak", "Num_Major_Vessels", "BMI"]
X = df[features]
y = df["Heart_Failure"]

# Standardizing numerical features
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# Splitting the dataset into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=42)

# Compute accuracy for different k values
k_values = list(range(1, 21))
accuracies = []

for k in k_values:
    knn = KNeighborsClassifier(n_neighbors=k)
    knn.fit(X_train, y_train)
    y_pred = knn.predict(X_test)
    accuracies.append(accuracy_score(y_test, y_pred))

# Plot KNN accuracy vs. k values
fig, ax = plt.subplots(figsize=(6, 4))
ax.plot(k_values, accuracies, marker="o", linestyle="-", color="b", label="Accuracy")
ax.axvline(x=15, color="r", linestyle="--", label="k=15")
ax.set_xlabel("Number of Neighbors (k)")
ax.set_ylabel("Accuracy")
ax.set_title("KNN Accuracy vs. Number of Neighbors")
ax.legend()
plt.grid(True)
